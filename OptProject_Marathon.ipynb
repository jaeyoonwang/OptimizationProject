# %%
using JuMP, Gurobi

m = Model(Gurobi.Optimizer)
set_optimizer_attribute(m, "TimeLimit", 300)

set_optimizer_attribute(m, "OutputFlag", 1)
set_optimizer_attribute(m, "LogFile", "gurobi_log.txt")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-08-21
# Set parameter TimeLimit to value 300
# Set parameter LogFile to value "gurobi_log.txt"

# %%
# number of weeks and days
T = 16
N = 7

# historical heart rate and weights for objective terms
HR_hist = 170
w1, w2, w3, w4 = 0.3, 1, 0.4, 0.7

# race distance and minimum total training distance
Race_Distance = 26.2
Min_Total_Distance = 400

# weekly distance progression limits
MaxWeeklyDist_hist = 18
Delta_Weekly_Distance = 1.3

# pacing history and weekly pace progression
FastestPace_hist = 8
Delta_Weekly_Pace = 0.005

# max distance per run and min distance per run when xt=1
Md, ed = 26.2, 3

# max and min pace per run when xt=1
Mp, ep = 20.0, 4.0

# define long run progression parameters
LongRun_InitialDistance = Race_Distance * 0.5       # half race distance start
LongRun_FinalDistance = 0.85 * Race_Distance        # target ~85% race distance for long run
Delta_longrun = (LongRun_FinalDistance - LongRun_InitialDistance) / (T - 1) 
# incremental increase in long run distance each week
# Out:
# 0.6113333333333333

# %%
# binary variables for training days
@variable(m, xt[1:T, 1:N], Bin)

# continuous daily distance (miles); not integers for flexibility
@variable(m, dt[1:T, 1:N] >= 0)

# continuous pace (min/mile)
@variable(m, pt[1:T, 1:N] >= 0)

# auxiliary variable for pace-readiness linking (unused in final constraints but kept)
@variable(m, st[1:T, 1:N] >= 0)

# binary variables reserved for other logic (yt for shortest/fastest runs, currently unused)
@variable(m, yt[1:T, 1:N], Bin)

# binary variables to identify specific long run conditions (zt)
@variable(m, zt[1:T], Bin)

# continuous variable for z_pace to track pace-readiness metric
@variable(m, z_pace >= 0)

# numerator and denominator for ratio calculations related to z_pace
@variable(m, numerator >= 0)
@variable(m, denominator >= 0)

# binary variables to identify tempo runs each week (yr), only for days 2 to N
@variable(m, yr[1:T, 2:N], Bin)
# Out:
# 2-dimensional DenseAxisArray{VariableRef,2,...} with index sets:
#     Dimension 1, Base.OneTo(16)
#     Dimension 2, 2:7
# And data, a 16×6 Matrix{VariableRef}:
#  yr[1,2]   yr[1,3]   yr[1,4]   yr[1,5]   yr[1,6]   yr[1,7]
#  yr[2,2]   yr[2,3]   yr[2,4]   yr[2,5]   yr[2,6]   yr[2,7]
#  yr[3,2]   yr[3,3]   yr[3,4]   yr[3,5]   yr[3,6]   yr[3,7]
#  yr[4,2]   yr[4,3]   yr[4,4]   yr[4,5]   yr[4,6]   yr[4,7]
#  yr[5,2]   yr[5,3]   yr[5,4]   yr[5,5]   yr[5,6]   yr[5,7]
#  yr[6,2]   yr[6,3]   yr[6,4]   yr[6,5]   yr[6,6]   yr[6,7]
#  yr[7,2]   yr[7,3]   yr[7,4]   yr[7,5]   yr[7,6]   yr[7,7]
#  yr[8,2]   yr[8,3]   yr[8,4]   yr[8,5]   yr[8,6]   yr[8,7]
#  yr[9,2]   yr[9,3]   yr[9,4]   yr[9,5]   yr[9,6]   yr[9,7]
#  yr[10,2]  yr[10,3]  yr[10,4]  yr[10,5]  yr[10,6]  yr[10,7]
#  yr[11,2]  yr[11,3]  yr[11,4]  yr[11,5]  yr[11,6]  yr[11,7]
#  yr[12,2]  yr[12,3]  yr[12,4]  yr[12,5]  yr[12,6]  yr[12,7]
#  yr[13,2]  yr[13,3]  yr[13,4]  yr[13,5]  yr[13,6]  yr[13,7]
#  yr[14,2]  yr[14,3]  yr[14,4]  yr[14,5]  yr[14,6]  yr[14,7]
#  yr[15,2]  yr[15,3]  yr[15,4]  yr[15,5]  yr[15,6]  yr[15,7]
#  yr[16,2]  yr[16,3]  yr[16,4]  yr[16,5]  yr[16,6]  yr[16,7]

# %%
# define the objective to maximize a weighted sum of total distance, pace-readiness, rest days, and training frequency
@objective(m, Max,
    w1 * sum(dt[t, n] for t in 1:T, n in 1:N) +
    w2 * HR_hist * z_pace +
    w3 * sum(7 - sum(xt[t, n] for n in 1:N) for t in 1:T) +
    w4 * sum(xt[t, n] for t in 1:T, n in 1:N)
)
# Out:
# 0.3 dt[1,1] + 0.3 dt[1,2] + 0.3 dt[1,3] + 0.3 dt[1,4] + 0.3 dt[1,5] + 0.3 dt[1,6] + 0.3 dt[1,7] + 0.3 dt[2,1] + 0.3 dt[2,2] + 0.3 dt[2,3] + 0.3 dt[2,4] + 0.3 dt[2,5] + 0.3 dt[2,6] + 0.3 dt[2,7] + 0.3 dt[3,1] + 0.3 dt[3,2] + 0.3 dt[3,3] + 0.3 dt[3,4] + 0.3 dt[3,5] + 0.3 dt[3,6] + 0.3 dt[3,7] + 0.3 dt[4,1] + 0.3 dt[4,2] + 0.3 dt[4,3] + 0.3 dt[4,4] + 0.3 dt[4,5] + 0.3 dt[4,6] + 0.3 dt[4,7] + 0.3 dt[5,1] + 0.3 dt[5,2] + [[...165 terms omitted...]] + 0.29999999999999993 xt[12,6] + 0.29999999999999993 xt[12,7] + 0.29999999999999993 xt[13,1] + 0.29999999999999993 xt[13,2] + 0.29999999999999993 xt[13,3] + 0.29999999999999993 xt[13,4] + 0.29999999999999993 xt[13,5] + 0.29999999999999993 xt[13,6] + 0.29999999999999993 xt[13,7] + 0.29999999999999993 xt[14,1] + 0.29999999999999993 xt[14,2] + 0.29999999999999993 xt[14,3] + 0.29999999999999993 xt[14,4] + 0.29999999999999993 xt[14,5] + 0.29999999999999993 xt[14,6] + 0.29999999999999993 xt[14,7] + 0.29999999999999993 xt[15,1] + 0.29999999999999993 xt[15,2] + 0.29999999999999993 xt[15,3] + 0.29999999999999993 xt[15,4] + 0.29999999999999993 xt[15,5] + 0.29999999999999993 xt[15,6] + 0.29999999999999993 xt[15,7] + 0.29999999999999993 xt[16,1] + 0.29999999999999993 xt[16,2] + 0.29999999999999993 xt[16,3] + 0.29999999999999993 xt[16,4] + 0.29999999999999993 xt[16,5] + 0.29999999999999993 xt[16,6] + 0.29999999999999993 xt[16,7] + 44.800000000000004

# %%
# set minimum total distance over the entire training period
@constraint(m, sum(dt[t, n] for t in 1:T, n in 1:N) >= Min_Total_Distance)

# set maximum weekly distance progression
@constraint(m, [t=1:T], sum(dt[t, n] for n in 1:N) <= MaxWeeklyDist_hist + (t - 1) * Delta_Weekly_Distance)

# set taper week: final week's mileage ≤ 80% of the previous week
@constraint(m, sum(dt[T, n] for n in 1:N) <= 0.7 * sum(dt[T-1, n] for n in 1:N))

# ensure exactly one tempo run (yr=1) per week (excluding day 1)
@constraint(m, [t=1:T], sum(yr[t,n] for n=2:N) == 1)

# long run pace ≤ 1.2x historic fastest adjusted per week
@constraint(m, [t=1:T], pt[t,1] ≤ 1.2 * (FastestPace_hist - (t-1)*Delta_Weekly_Pace) * xt[t,1])

# tempo run pace ≤ fastest adjusted pace if yr=1; otherwise ≤ 1.1x adjusted pace
@constraint(m, [t=1:T, n=2:N],
    pt[t,n] ≤ (FastestPace_hist - (t-1)*Delta_Weekly_Pace)*yr[t,n] + 
              1.1*(FastestPace_hist - (t-1)*Delta_Weekly_Pace)*(1 - yr[t,n]) 
)

# tempo run day must be a training day
@constraint(m, [t=1:T, n=2:N], yr[t,n] ≤ xt[t,n])

# ≤5 training days per week
@constraint(m, [t=1:T], sum(xt[t, n] for n in 1:N) <= 5)

# no run on day 2 if day 1 is a run
@constraint(m, [t=1:T], xt[t,1] + xt[t,2] <= 1)

# long run ≥ each other run in that week; non-long runs ≤9 miles
@constraint(m, [t=1:T, n=2:N], dt[t, 1] >= dt[t, n])
@constraint(m, [t=1:T, n=2:N], dt[t, n] <= 9)

# long run progression upper bound (no strict lower bound)
@constraint(m, [t=1:T], dt[t, 1] <= LongRun_InitialDistance + (t-1)*Delta_longrun)

# ensure at least one long run hits 80%-100% range (zt indicates weeks with qualifying long run)
@constraint(m, sum(zt[t] for t in 1:T) >= 1)
@constraint(m, [t=1:T], dt[t, 1] >= ed * zt[t])
@constraint(m, [t=1:T], dt[t, 1] <= LongRun_FinalDistance * zt[t])

# taper the final week's long run to ≤80% of previous week's long run
@constraint(m, dt[T, 1] <= 0.6 * dt[T-1, 1])

# link distance and runs: distance only if xt=1; pace only if xt=1
@constraint(m, [t=1:T, n=1:N], dt[t, n] <= Md * xt[t, n])
@constraint(m, [t=1:T, n=1:N], dt[t, n] >= ed * xt[t, n])
@constraint(m, [t=1:T, n=1:N], pt[t, n] <= Mp * xt[t, n])
@constraint(m, [t=1:T, n=1:N], pt[t, n] >= ep * xt[t, n])

# pace-readiness linking: numerator/denominator for z_pace, encouraging better pace
@constraint(m, numerator == sum(xt[t, n] * pt[t, n] for t in 1:T, n in 1:N))
@constraint(m, denominator == sum(xt[t, n] for t in 1:T, n in 1:N))
@constraint(m, numerator >= z_pace * denominator)
# Out:
# -z_pace*denominator + numerator ≥ 0

# %%
optimize!(m)

status = termination_status(m)
if status == MOI.OPTIMAL
    println("Optimal solution found!")
elseif status == MOI.TIME_LIMIT
    println("Solver reached the time limit.")
else
    println("Solver did not converge: ", status)
end

println("\nMarathon Training Plan:")
if status == MOI.OPTIMAL
    for t in 1:T
        if t == T
            println("Week $t (Taper Week):")
        else
            println("Week $t:")
        end

        tempo_day = 0
        for n in 2:N
            if value(yr[t,n]) > 0.5
                tempo_day = n
                break
            end
        end

        for n in 1:N
            run_status = value(xt[t, n])
            if run_status > 0.5
                distance = value(dt[t, n])
                raw_pace = value(pt[t, n])

                pace_minutes = Int(floor(raw_pace))
                pace_seconds = Int(round((raw_pace - floor(raw_pace))*60))
                sec_str = lpad(string(pace_seconds), 2, '0')

                labels = ""
                if n == 1
                    labels *= "(long run)"
                elseif n == tempo_day
                    labels *= "(tempo)"
                end

                println("  Day $n: $(round(distance, digits=1)) miles, $pace_minutes:$sec_str pace $labels")
            else
                println("  Day $n: Rest day")
            end
        end
        println("")
    end
else
    println("No solution available.")
end
# Out:
# Set parameter TimeLimit to value 300
# Set parameter LogFile to value "gurobi_log.txt"
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.4.0 23E214)
#
# CPU model: Apple M3 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 965 rows, 675 columns and 2289 nonzeros
# Model fingerprint: 0x302070af
# Model has 2 quadratic constraints
# Variable types: 339 continuous, 336 integer (336 binary)
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+01]
#   QMatrix range    [1e+00, 1e+00]
#   QLMatrix range   [1e+00, 1e+00]
#   Objective range  [3e-01, 2e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 4e+02]
# Presolve removed 433 rows and 320 columns
# Presolve time: 0.00s
# Presolved: 775 rows, 435 columns, 2229 nonzeros
# Presolved model has 1 bilinear constraint(s)
#
# Solving non-convex MIQCP
#
# Variable types: 274 continuous, 161 integer (160 binary)
#
# Root relaxation: objective 5.098889e+03, 489 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5098.88914    0   13          - 5098.88914      -     -    0s
#      0     0 3780.43912    0   38          - 3780.43912      -     -    0s
#      0     0 2670.67857    0    3          - 2670.67857      -     -    0s
#      0     0 2264.17687    0    4          - 2264.17687      -     -    0s
#      0     0 2071.51416    0    6          - 2071.51416      -     -    0s
#      0     0 1971.01870    0    8          - 1971.01870      -     -    0s
# H    0     0                    1669.9045722 1971.01870  18.0%     -    0s
#      0     0 1835.81299    0    3 1669.90457 1835.81299  9.94%     -    0s
#      0     0 1798.05274    0    5 1669.90457 1798.05274  7.67%     -    0s
# H    0     0                    1679.5772077 1798.05274  7.05%     -    0s
# H    0     0                    1687.3395000 1798.05274  6.56%     -    0s
#      0     0 1782.59301    0    5 1687.33950 1782.59301  5.65%     -    0s
#      0     0 1777.22630    0    6 1687.33950 1777.22630  5.33%     -    0s
#      0     0 1775.30928    0    5 1687.33950 1775.30928  5.21%     -    0s
#      0     0 1774.60497    0    4 1687.33950 1774.60497  5.17%     -    0s
#      0     0 1774.35008    0    6 1687.33950 1774.35008  5.16%     -    0s
#      0     0 1774.25155    0    6 1687.33950 1774.25155  5.15%     -    0s
#      0     0 1774.21047    0   15 1687.33950 1774.21047  5.15%     -    0s
#      0     0 1774.08145    0   11 1687.33950 1774.08145  5.14%     -    0s
#      0     0 1772.12252    0    8 1687.33950 1772.12252  5.02%     -    0s
#      0     0 1772.10693    0   13 1687.33950 1772.10693  5.02%     -    0s
#      0     0 1770.67184    0   11 1687.33950 1770.67184  4.94%     -    0s
#      0     0 1770.08890    0   10 1687.33950 1770.08890  4.90%     -    0s
#      0     0 1769.87083    0   17 1687.33950 1769.87083  4.89%     -    0s
#      0     0 1769.79453    0   18 1687.33950 1769.79453  4.89%     -    0s
#      0     0 1769.76020    0   27 1687.33950 1769.76020  4.88%     -    0s
#      0     0 1769.74465    0   26 1687.33950 1769.74465  4.88%     -    0s
#      0     0 1769.39134    0   30 1687.33950 1769.39134  4.86%     -    0s
#      0     0 1768.49843    0   34 1687.33950 1768.49843  4.81%     -    0s
#      0     0 1768.13103    0   39 1687.33950 1768.13103  4.79%     -    0s
#      0     0 1767.36757    0   41 1687.33950 1767.36757  4.74%     -    0s
#      0     0 1767.16718    0   39 1687.33950 1767.16718  4.73%     -    0s
#      0     0 1766.54140    0   45 1687.33950 1766.54140  4.69%     -    0s
#      0     0 1766.32846    0   49 1687.33950 1766.32846  4.68%     -    0s
#      0     0 1766.13236    0   47 1687.33950 1766.13236  4.67%     -    0s
#      0     0 1765.52043    0   49 1687.33950 1765.52043  4.63%     -    0s
#      0     0 1765.46795    0   53 1687.33950 1765.46795  4.63%     -    0s
#      0     0 1765.37702    0   52 1687.33950 1765.37702  4.62%     -    0s
#      0     0 1765.37377    0   54 1687.33950 1765.37377  4.62%     -    0s
#      0     0 1765.24582    0   56 1687.33950 1765.24582  4.62%     -    0s
#      0     0 1765.24564    0   56 1687.33950 1765.24564  4.62%     -    0s
#      0     2 1765.24564    0   56 1687.33950 1765.24564  4.62%     -    0s
#
# Cutting planes:
#   Gomory: 22
#   Lift-and-project: 3
#   MIR: 5
#   Flow cover: 19
#   RLT: 41
#
# Explored 28 nodes (2922 simplex iterations) in 0.23 seconds (0.23 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1687.34 1679.58 1669.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.687339500000e+03, best bound 1.687339500000e+03, gap 0.0000%
#
# User-callback calls 881, time in user-callback 0.00 sec
# Optimal solution found!
#
# Half Marathon Training Plan:
# Week 1:
#   Day 1: 6.0 miles, 9:36 pace (long run)
#   Day 2: Rest day
#   Day 3: 3.0 miles, 8:48 pace
#   Day 4: 3.0 miles, 8:00 pace (tempo)
#   Day 5: 3.0 miles, 8:48 pace
#   Day 6: Rest day
#   Day 7: 3.0 miles, 8:48 pace
#
# Week 2:
#   Day 1: 7.3 miles, 9:36 pace (long run)
#   Day 2: Rest day
#   Day 3: Rest day
#   Day 4: 3.0 miles, 8:48 pace
#   Day 5: 3.0 miles, 7:60 pace (tempo)
#   Day 6: 3.0 miles, 8:48 pace
#   Day 7: 3.0 miles, 8:48 pace
#
# Week 3:
#   Day 1: 8.6 miles, 9:35 pace (long run)
#   Day 2: Rest day
#   Day 3: Rest day
#   Day 4: 3.0 miles, 7:59 pace (tempo)
#   Day 5: 3.0 miles, 8:47 pace
#   Day 6: 3.0 miles, 8:47 pace
#   Day 7: 3.0 miles, 8:47 pace
#
# Week 4:
#   Day 1: 9.9 miles, 9:35 pace (long run)
#   Day 2: Rest day
#   Day 3: 3.0 miles, 8:47 pace
#   Day 4: Rest day
#   Day 5: 3.0 miles, 8:47 pace
#   Day 6: 3.0 miles, 8:47 pace
#   Day 7: 3.0 miles, 7:59 pace (tempo)
#
# Week 5:
#   Day 1: 11.2 miles, 9:35 pace (long run)
#   Day 2: Rest day
#   Day 3: Rest day
#   Day 4: 3.0 miles, 8:47 pace
#   Day 5: 3.0 miles, 8:47 pace
#   Day 6: 3.0 miles, 8:47 pace
#   Day 7: 3.0 miles, 7:59 pace (tempo)
#
# Week 6:
#   Day 1: 12.5 miles, 9:34 pace (long run)
#   Day 2: Rest day
#   Day 3: Rest day
#   Day 4: 3.0 miles, 8:46 pace
#   Day 5: 3.0 miles, 8:46 pace
#   Day 6: 3.0 miles, 8:46 pace
#   Day 7: 3.0 miles, 7:58 pace (tempo)
#
# Week 7:
#   Day 1: 13.8 miles, 9:34 pace (long run)
#   Day 2: Rest day
#   Day 3: Rest day
#   Day 4: 3.0 miles, 8:46 pace
#   Day 5: 3.0 miles, 8:46 pace
#   Day 6: 3.0 miles, 8:46 pace
#   Day 7: 3.0 miles, 7:58 pace (tempo)
#
# Week 8:
#   Day 1: 6.0 miles, 9:33 pace (long run)
#   Day 2: Rest day
#   Day 3: 6.0 miles, 7:58 pace (tempo)
#   Day 4: 6.0 miles, 8:46 pace
#   Day 5: 3.0 miles, 8:46 pace
#   Day 6: Rest day
#   Day 7: 6.0 miles, 8:46 pace
#
# Week 9:
#   Day 1: 6.4 miles, 9:33 pace (long run)
#   Day 2: Rest day
#   Day 3: Rest day
#   Day 4: 6.4 miles, 8:45 pace
#   Day 5: 6.4 miles, 8:45 pace
#   Day 6: 3.0 miles, 7:58 pace (tempo)
#   Day 7: 6.4 miles, 8:45 pace
#
# Week 10:
#   Day 1: 5.9 miles, 9:33 pace (long run)
#   Day 2: Rest day
#   Day 3: 5.9 miles, 8:45 pace
#   Day 4: Rest day
#   Day 5: 5.9 miles, 8:45 pace
#   Day 6: 5.9 miles, 7:57 pace (tempo)
#   Day 7: 5.9 miles, 8:45 pace
#
# Week 11:
#   Day 1: 6.2 miles, 9:32 pace (long run)
#   Day 2: Rest day
#   Day 3: 6.2 miles, 8:45 pace
#   Day 4: 6.2 miles, 8:45 pace
#   Day 5: 6.2 miles, 8:45 pace
#   Day 6: Rest day
#   Day 7: 6.2 miles, 7:57 pace (tempo)
#
# Week 12:
#   Day 1: 19.8 miles, 9:32 pace (long run)
#   Day 2: Rest day
#   Day 3: Rest day
#   Day 4: 3.0 miles, 8:44 pace
#   Day 5: 3.5 miles, 8:44 pace
#   Day 6: 3.0 miles, 7:57 pace (tempo)
#   Day 7: 3.0 miles, 8:44 pace
#
# Week 13:
#   Day 1: 6.7 miles, 9:32 pace (long run)
#   Day 2: Rest day
#   Day 3: 6.7 miles, 8:44 pace
#   Day 4: 6.7 miles, 7:56 pace (tempo)
#   Day 5: Rest day
#   Day 6: 6.7 miles, 8:44 pace
#   Day 7: 6.7 miles, 8:44 pace
#
# Week 14:
#   Day 1: 21.0 miles, 9:31 pace (long run)
#   Day 2: Rest day
#   Day 3: 3.0 miles, 8:44 pace
#   Day 4: 3.0 miles, 8:44 pace
#   Day 5: Rest day
#   Day 6: 3.0 miles, 8:44 pace
#   Day 7: 4.9 miles, 7:56 pace (tempo)
#
# Week 15:
#   Day 1: 21.7 miles, 9:31 pace (long run)
#   Day 2: Rest day
#   Day 3: 3.0 miles, 8:43 pace
#   Day 4: 5.5 miles, 8:43 pace
#   Day 5: Rest day
#   Day 6: 3.0 miles, 7:56 pace (tempo)
#   Day 7: 3.0 miles, 8:43 pace
#
# Week 16 (Taper Week):
#   Day 1: 13.0 miles, 9:31 pace (long run)
#   Day 2: Rest day
#   Day 3: 3.0 miles, 8:43 pace
#   Day 4: Rest day
#   Day 5: 3.0 miles, 7:55 pace (tempo)
#   Day 6: 3.3 miles, 8:43 pace
#   Day 7: 3.0 miles, 8:43 pace
